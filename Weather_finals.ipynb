# %%
import pandas as pd
df=pd.read_csv("ww.csv")
df
# Out:
#         Humidity  Wind Speed     Pressure  Temperature
# 0      49.963210   17.488459  1018.716506   146.759016
# 1      96.057145   26.136137  1010.668160   181.302235
# 2      78.559515   19.693337  1033.402434   165.377682
# 3      67.892679    2.915590   999.854030   146.392050
# 4      32.481491    6.495308  1016.453539   128.411913
# ...          ...         ...          ...          ...
# 14995  72.070679   33.329641   998.703825   172.315123
# 14996  34.223867   26.173847  1004.375318   142.251959
# 14997  24.099163    0.680955  1005.903359   116.375480
# 14998  74.636927   14.035169  1002.906992   159.085230
# 14999  40.086322    9.008929  1028.395971   129.088594
#
# [15000 rows x 4 columns]

# %%
#summary of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Humidity     15000 non-null  float64
#  1   Wind Speed   15000 non-null  float64
#  2   Pressure     15000 non-null  float64
#  3   Temperature  15000 non-null  float64
# dtypes: float64(4)
# memory usage: 468.9 KB

# %%
# Minimum Value of each column
df.min()
# Out:
# Humidity        20.000931
# Wind Speed       0.001684
# Pressure       990.000249
# Temperature     84.257025
# dtype: float64

# %%
#Maximum Value of each column
df.max()
# Out:
# Humidity         99.984412
# Wind Speed       59.698273
# Pressure       1034.998747
# Temperature     233.058708
# dtype: float64

# %%
#Mean value of each column
df.mean()
# Out:
# Humidity         59.725178
# Wind Speed       17.674164
# Pressure       1012.438244
# Temperature     152.144554
# dtype: float64

# %%
#Median value of each column
df.median()
# Out:
# Humidity         59.477786
# Wind Speed       17.762722
# Pressure       1012.359387
# Temperature     152.137571
# dtype: float64

# %%
#Count total number of values in each column
df.count()
# Out:
# Humidity       15000
# Wind Speed     15000
# Pressure       15000
# Temperature    15000
# dtype: int64

# %%
#Provide a tuple with rows and columns
df.shape
# Out:
# (15000, 4)

# %%
#Calculates Standard deviation
df.std()
# Out:
# Humidity       23.095266
# Wind Speed     10.140734
# Pressure       13.008862
# Temperature    17.522552
# dtype: float64

# %%
#represents the correlation between different columns
df.corr()
# Out:
#              Humidity  Wind Speed  Pressure  Temperature
# Humidity     1.000000    0.020297  0.002224     0.862907
# Wind Speed   0.020297    1.000000 -0.010252     0.443929
# Pressure     0.002224   -0.010252  1.000000    -0.114019
# Temperature  0.862907    0.443929 -0.114019     1.000000

# %%
#Provides summary of statistics
df.describe()
# Out:
#            Humidity    Wind Speed      Pressure   Temperature
# count  15000.000000  15000.000000  15000.000000  15000.000000
# mean      59.725178     17.674164   1012.438244    152.144554
# std       23.095266     10.140734     13.008862     17.522552
# min       20.000931      0.001684    990.000249     84.257025
# 25%       39.729118      9.023754   1001.116578    138.857982
# 50%       59.477786     17.762722   1012.359387    152.137571
# 75%       79.868856     26.240603   1023.703276    165.431484
# max       99.984412     59.698273   1034.998747    233.058708

# %%
#Returns bydefault first 5 rows of dataset
df.head()
# Out:
#     Humidity  Wind Speed     Pressure  Temperature
# 0  49.963210   17.488459  1018.716506   146.759016
# 1  96.057145   26.136137  1010.668160   181.302235
# 2  78.559515   19.693337  1033.402434   165.377682
# 3  67.892679    2.915590   999.854030   146.392050
# 4  32.481491    6.495308  1016.453539   128.411913

# %%
#Returns bydefault last 5 rows of dataset
df.tail()
# Out:
#         Humidity  Wind Speed     Pressure  Temperature
# 14995  72.070679   33.329641   998.703825   172.315123
# 14996  34.223867   26.173847  1004.375318   142.251959
# 14997  24.099163    0.680955  1005.903359   116.375480
# 14998  74.636927   14.035169  1002.906992   159.085230
# 14999  40.086322    9.008929  1028.395971   129.088594

# %%
#Boxplot of Humidity column
import seaborn as sns
sns.boxplot(x='Humidity',data=df)
# Out:
# <Axes: xlabel='Humidity'>

# %%
sns.boxplot(x='Wind Speed',data=df)
# Out:
# <Axes: xlabel='Wind Speed'>

# %%
sns.boxplot(x='Pressure',data=df)
# Out:
# <Axes: xlabel='Pressure'>

# %%
sns.boxplot(y='Temperature',data=df)
# Out:
# <Axes: ylabel='Temperature'>

# %%
sns.scatterplot(x = 'Humidity', y='Temperature',data = df)
# Out:
# <Axes: xlabel='Humidity', ylabel='Temperature'>

# %%
sns.scatterplot(x = 'Wind Speed', y='Temperature',data = df)
# Out:
# <Axes: xlabel='Wind Speed', ylabel='Temperature'>

# %%
sns.scatterplot(x = 'Pressure', y='Temperature',data = df)
# Out:
# <Axes: xlabel='Pressure', ylabel='Temperature'>

# %%
sns.regplot(x = 'Humidity', y='Temperature',data = df,color='r')
# Out:
# <Axes: xlabel='Humidity', ylabel='Temperature'>

# %%
sns.regplot(x = 'Wind Speed', y='Temperature',data = df,color='r')
# Out:
# <Axes: xlabel='Wind Speed', ylabel='Temperature'>

# %%
sns.regplot(x = 'Pressure', y='Temperature',data = df,color='r')
# Out:
# <Axes: xlabel='Pressure', ylabel='Temperature'>

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
df.isnull().sum()
# Out:
# Humidity       0
# Wind Speed     0
# Pressure       0
# Temperature    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import pandas as pd
import numpy as np
Q1 = df['Pressure'].quantile(0.25)
Q3 = df['Pressure'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df_cleaned = df[(df['Pressure'] >= lower_bound) & (df['Pressure'] <= upper_bound)]
print(df_cleaned)
# Out:
#         Humidity  Wind Speed     Pressure  Temperature
# 0      49.963210   17.488459  1018.716506   146.759016
# 1      96.057145   26.136137  1010.668160   181.302235
# 2      78.559515   19.693337  1033.402434   165.377682
# 3      67.892679    2.915590   999.854030   146.392050
# 4      32.481491    6.495308  1016.453539   128.411913
# ...          ...         ...          ...          ...
# 14995  72.070679   33.329641   998.703825   172.315123
# 14996  34.223867   26.173847  1004.375318   142.251959
# 14997  24.099163    0.680955  1005.903359   116.375480
# 14998  74.636927   14.035169  1002.906992   159.085230
# 14999  40.086322    9.008929  1028.395971   129.088594
#
# [15000 rows x 4 columns]

# %%
sns.boxplot(x=df_cleaned['Pressure'])
# Out:
# <Axes: xlabel='Pressure'>

# %%
import pandas as pd
import numpy as np
Q1 = df['Temperature'].quantile(0.25)
Q3 = df['Temperature'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df_cleaned = df[(df['Temperature'] >= lower_bound) & (df['Temperature'] <= upper_bound)]
print(df_cleaned)
# Out:
#         Humidity  Wind Speed     Pressure  Temperature
# 0      49.963210   17.488459  1018.716506   146.759016
# 1      96.057145   26.136137  1010.668160   181.302235
# 2      78.559515   19.693337  1033.402434   165.377682
# 3      67.892679    2.915590   999.854030   146.392050
# 4      32.481491    6.495308  1016.453539   128.411913
# ...          ...         ...          ...          ...
# 14995  72.070679   33.329641   998.703825   172.315123
# 14996  34.223867   26.173847  1004.375318   142.251959
# 14997  24.099163    0.680955  1005.903359   116.375480
# 14998  74.636927   14.035169  1002.906992   159.085230
# 14999  40.086322    9.008929  1028.395971   129.088594
#
# [14972 rows x 4 columns]

# %%
sns.boxplot(y=df_cleaned['Temperature'])
# Out:
# <Axes: ylabel='Temperature'>

# %%
df=df_cleaned.reset_index()
df
# Out:
#        index   Humidity  Wind Speed     Pressure  Temperature
# 0          0  49.963210   17.488459  1018.716506   146.759016
# 1          1  96.057145   26.136137  1010.668160   181.302235
# 2          2  78.559515   19.693337  1033.402434   165.377682
# 3          3  67.892679    2.915590   999.854030   146.392050
# 4          4  32.481491    6.495308  1016.453539   128.411913
# ...      ...        ...         ...          ...          ...
# 14967  14995  72.070679   33.329641   998.703825   172.315123
# 14968  14996  34.223867   26.173847  1004.375318   142.251959
# 14969  14997  24.099163    0.680955  1005.903359   116.375480
# 14970  14998  74.636927   14.035169  1002.906992   159.085230
# 14971  14999  40.086322    9.008929  1028.395971   129.088594
#
# [14972 rows x 5 columns]

# %%
df.drop(columns=['index'],inplace=True)
df
# Out:
#         Humidity  Wind Speed     Pressure  Temperature
# 0      49.963210   17.488459  1018.716506   146.759016
# 1      96.057145   26.136137  1010.668160   181.302235
# 2      78.559515   19.693337  1033.402434   165.377682
# 3      67.892679    2.915590   999.854030   146.392050
# 4      32.481491    6.495308  1016.453539   128.411913
# ...          ...         ...          ...          ...
# 14967  72.070679   33.329641   998.703825   172.315123
# 14968  34.223867   26.173847  1004.375318   142.251959
# 14969  24.099163    0.680955  1005.903359   116.375480
# 14970  74.636927   14.035169  1002.906992   159.085230
# 14971  40.086322    9.008929  1028.395971   129.088594
#
# [14972 rows x 4 columns]

# %%
#selecting independent variables
x=df.iloc[:,0:3]
x
# Out:
#         Humidity  Wind Speed     Pressure
# 0      49.963210   17.488459  1018.716506
# 1      96.057145   26.136137  1010.668160
# 2      78.559515   19.693337  1033.402434
# 3      67.892679    2.915590   999.854030
# 4      32.481491    6.495308  1016.453539
# ...          ...         ...          ...
# 14967  72.070679   33.329641   998.703825
# 14968  34.223867   26.173847  1004.375318
# 14969  24.099163    0.680955  1005.903359
# 14970  74.636927   14.035169  1002.906992
# 14971  40.086322    9.008929  1028.395971
#
# [14972 rows x 3 columns]

# %%
#Selecting dependent variable
y=df.iloc[:,-1]
y
# Out:
# 0        146.759016
# 1        181.302235
# 2        165.377682
# 3        146.392050
# 4        128.411913
#             ...
# 14967    172.315123
# 14968    142.251959
# 14969    116.375480
# 14970    159.085230
# 14971    129.088594
# Name: Temperature, Length: 14972, dtype: float64

# %%
# splitting data for training and testing
# model gets trained on x_train and y_train and performance get evaluated on x_test and y_test
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.08,random_state=42)

# %%
x_train
# Out:
#         Humidity  Wind Speed     Pressure
# 9785   94.428094   30.233440  1019.114218
# 1217   41.860762   28.159555  1005.244936
# 13064  47.434809    3.878406  1032.042136
# 3495   84.211225   13.043663  1018.855176
# 7258   48.399609    4.358041  1013.761555
# ...          ...         ...          ...
# 5191   98.635750   13.697297  1031.109872
# 13418  93.031678   23.456811  1018.612636
# 5390   39.519624   25.786472   991.909579
# 860    61.951222   20.583905   993.010663
# 7270   24.286125   14.554192  1032.828773
#
# [13774 rows x 3 columns]

# %%
y_train
# Out:
# 9785     183.161932
# 1217     106.682025
# 13064    130.803170
# 3495     166.772328
# 7258     134.420574
#             ...
# 5191     167.450110
# 13418    179.250113
# 5390     148.868658
# 860      158.630425
# 7270     123.252601
# Name: Temperature, Length: 13774, dtype: float64

# %%
# Standard Scaling
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)
x_test
# Out:
# array([[-1.51804103,  1.67907029,  1.34277999],
#        [ 0.48623609, -0.52534286,  1.4351908 ],
#        [-0.45390089, -1.29839547, -1.35356178],
#        ...,
#        [ 0.77431206, -1.34677905, -1.43861053],
#        [ 1.08692061, -1.07848984, -0.54444034],
#        [-0.91710689,  0.65213717,  1.50658843]], shape=(1198, 3))

# %%
#LINEAR REGRESSION
from sklearn.linear_model import LinearRegression
regression=LinearRegression(n_jobs=-1)
regression.fit(x_train,y_train)
regression
y_pred=regression.predict(x_test)

# %%
#regression.fit(x_train,y_train)

# %%
#regression

# %%
y_pred=regression.predict(x_test)

# %%
from sklearn.metrics  import r2_score
score=r2_score(y_test,y_pred)
print(score)
# Out:
# 0.9644510908298289

# %%
user_input = []
for feature in x.columns:
  value = float(input(f"Enter value for {feature}: "))
  user_input.append(value)

# Reshape and scale user input
user_input = np.array(user_input).reshape(1, -1)
user_input_scaled = scaler.transform(user_input)

# Predict profit for user input
predicted_temp = regression.predict(user_input_scaled)

print(f"Predicted temperature with multilinear regression: {predicted_temp[0]}")
# Out:
# Enter value for Humidity:  96.057145
# Enter value for Wind Speed:  26.136137
# Enter value for Pressure:  1034.210282
# Predicted temperature with multilinear regression: 178.52182422971407
# C:\Users\vansh\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
df
# Out:
#         Humidity  Wind Speed     Pressure  Temperature
# 0      49.963210   17.488459  1018.716506   146.759016
# 1      96.057145   26.136137  1010.668160   181.302235
# 2      78.559515   19.693337  1033.402434   165.377682
# 3      67.892679    2.915590   999.854030   146.392050
# 4      32.481491    6.495308  1016.453539   128.411913
# ...          ...         ...          ...          ...
# 14967  72.070679   33.329641   998.703825   172.315123
# 14968  34.223867   26.173847  1004.375318   142.251959
# 14969  24.099163    0.680955  1005.903359   116.375480
# 14970  74.636927   14.035169  1002.906992   159.085230
# 14971  40.086322    9.008929  1028.395971   129.088594
#
# [14972 rows x 4 columns]

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor(n_neighbors=5) 
knn.fit(x_train, y_train)
y_pred = knn.predict(x_test)
score = r2_score(y_pred, y_test)
print(score)
# Out:
# 0.9523629210122447

# %%
user_input = []
for feature in x.columns:
  value = float(input(f"Enter value for {feature}: "))
  user_input.append(value)

# Reshape and scale user input
user_input = np.array(user_input).reshape(1, -1)
user_input_scaled = scaler.transform(user_input)

# Predict profit for user input
predicted_temp = knn.predict(user_input_scaled)

print(f"Predicted temperature with KNN regression: {predicted_temp[0]}")
# Out:
# Enter value for Humidity:  0
# Enter value for Wind Speed:  2
# Enter value for Pressure:  23
# Predicted temperature with KNN regression: 155.08589034785962
# C:\Users\vansh\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
from sklearn.svm import SVR
clf = SVR(kernel='linear')
clf.fit(x_train, y_train)

# Make predictions
y_pred = clf.predict(x_test)

r2 = r2_score(y_test, y_pred)
print(r2)
# Out:
# 0.9853386751944636

# %%
user_input = []
for feature in x.columns:
  value = float(input(f"Enter value for {feature}: "))
  user_input.append(value)

# Reshape and scale user input
user_input = np.array(user_input).reshape(1, -1)
user_input_scaled = scaler.transform(user_input)

# Predict profit for user input
predicted_temp = clf.predict(user_input_scaled)

print(f"Predicted temperature with SVM regression: {predicted_temp[0]}")
# Out:
# Enter value for Humidity:  78.559515
# Enter value for Wind Speed:  19.693337
# Enter value for Pressure:  	1029.656791
# Predicted temperature with SVM regression: 161.494669841406
# C:\Users\HP\vanshu\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
df
# Out:
#         Humidity  Wind Speed     Pressure  Temperature
# 0      49.963210   17.488459  1006.693077   145.331225
# 1      96.057145   26.136137  1034.403088   165.669988
# 2      78.559515   19.693337  1029.656791   161.166444
# 3      67.892679    2.915590  1020.309354   158.458275
# 4      32.481491    6.495308  1009.569241   144.024266
# ...          ...         ...          ...          ...
# 14995  72.070679   33.329641   997.158044   143.164792
# 14996  34.223867   26.173847  1023.660355   144.480725
# 14997  24.099163    0.680955  1003.434061   138.531646
# 14998  74.636927   14.035169  1014.538453   156.725633
# 14999  40.086322    9.008929  1016.214783   147.734672
#
# [15000 rows x 4 columns]

# %%
df
# Out:
#         Humidity  Wind Speed     Pressure  Temperature
# 0      49.963210   17.488459  1006.693077   145.331225
# 1      96.057145   26.136137  1034.403088   165.669988
# 2      78.559515   19.693337  1029.656791   161.166444
# 3      67.892679    2.915590  1020.309354   158.458275
# 4      32.481491    6.495308  1009.569241   144.024266
# ...          ...         ...          ...          ...
# 14995  72.070679   33.329641   997.158044   143.164792
# 14996  34.223867   26.173847  1023.660355   144.480725
# 14997  24.099163    0.680955  1003.434061   138.531646
# 14998  74.636927   14.035169  1014.538453   156.725633
# 14999  40.086322    9.008929  1016.214783   147.734672
#
# [15000 rows x 4 columns]

# %%
#DECISION TREE REGRESSOR
from sklearn.tree import DecisionTreeRegressor
dt_regressor = DecisionTreeRegressor(random_state=890)
treemodel=DecisionTreeRegressor(max_depth=2)
treemodel
# Out:
# DecisionTreeRegressor(max_depth=2)

# %%
#from sklearn.tree import DecisionTreeRegressor

# %%
#dt_regressor = DecisionTreeRegressor(random_state=42)

# %%
#treemodel=DecisionTreeRegressor(max_depth=2)
treemodel
# Out:
# DecisionTreeRegressor(max_depth=2)

# %%
treemodel.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=2)

# %%
#constructing tree
import matplotlib.pyplot as plt
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(treemodel,filled=True)
# Out:
# [Text(0.5, 0.8333333333333334, 'x[0] <= -0.081\nsquared_error = 67.232\nsamples = 13720\nvalue = 149.554'),
#  Text(0.25, 0.5, 'x[2] <= -0.24\nsquared_error = 30.64\nsamples = 6587\nvalue = 143.353'),
#  Text(0.125, 0.16666666666666666, 'squared_error = 19.92\nsamples = 2655\nvalue = 139.561'),
#  Text(0.375, 0.16666666666666666, 'squared_error = 21.608\nsamples = 3932\nvalue = 145.914'),
#  Text(0.75, 0.5, 'x[2] <= 0.07\nsquared_error = 32.722\nsamples = 7133\nvalue = 155.281'),
#  Text(0.625, 0.16666666666666666, 'squared_error = 23.055\nsamples = 3757\nvalue = 152.3'),
#  Text(0.875, 0.16666666666666666, 'squared_error = 22.59\nsamples = 3376\nvalue = 158.598')]

# %%
#postprunning technique
treemodel=DecisionTreeRegressor()
treemodel
treemodel.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
#treemodel.fit(x_train,y_train)

# %%
y_pred = treemodel.predict(x_test)
y_pred
# Out:
# array([144.73966292, 140.64348918, 148.18168005, ..., 147.89340929,
#        154.43716081, 154.73796136])

# %%
from sklearn.metrics import r2_score
score = r2_score(y_pred,y_test)
print(score)
# Out:
# 0.9641564622187867

# %%
# Using Hyperparameters to improve accuracy 
param_grid = {
    'max_depth': [None, 10, 20, 30, 40, 50],
    'min_samples_split': [2, 5, 10, 15, 20],
    'min_samples_leaf': [1, 2, 5, 10],
    'max_features': ['auto', 'sqrt', 'log2', None],
    'splitter': ['best', 'random']
}

# %%
from sklearn.model_selection import RandomizedSearchCV
treemodel=DecisionTreeRegressor()
cv=RandomizedSearchCV(treemodel,param_distributions=param_grid,cv=5)
cv.fit(x_train,y_train)
cv.best_params_
cv.predict(x_test)
# Out:
# C:\Users\HP\vanshu\Lib\site-packages\sklearn\tree\_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# C:\Users\HP\vanshu\Lib\site-packages\sklearn\tree\_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# C:\Users\HP\vanshu\Lib\site-packages\sklearn\tree\_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# C:\Users\HP\vanshu\Lib\site-packages\sklearn\tree\_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# ...

# %%
cv.best_params_
# Out:
# {'splitter': 'best',
#  'min_samples_split': 10,
#  'min_samples_leaf': 2,
#  'max_features': None,
#  'max_depth': 50}

# %%
cv.predict(x_test)
# Out:
# array([145.04376153, 141.04032496, 146.91143026, ..., 147.2701643 ,
#        155.53364024, 155.19407747])

# %%
y_pred=cv.predict(x_test)
from sklearn.metrics import r2_score
score = r2_score(y_pred,y_test)
print(score)
# Out:
# 0.9723303785383794

# %%
df
# Out:
#         Humidity  Wind Speed     Pressure  Temperature
# 0      49.963210   17.488459  1006.693077   145.331225
# 1      96.057145   26.136137  1034.403088   165.669988
# 2      78.559515   19.693337  1029.656791   161.166444
# 3      67.892679    2.915590  1020.309354   158.458275
# 4      32.481491    6.495308  1009.569241   144.024266
# ...          ...         ...          ...          ...
# 14909  72.070679   33.329641   997.158044   143.164792
# 14910  34.223867   26.173847  1023.660355   144.480725
# 14911  24.099163    0.680955  1003.434061   138.531646
# 14912  74.636927   14.035169  1014.538453   156.725633
# 14913  40.086322    9.008929  1016.214783   147.734672
#
# [14914 rows x 4 columns]

# %%
user_input = []
for feature in x.columns:
  value = float(input(f"Enter value for {feature}: "))
  user_input.append(value)

# Reshape and scale user input                    144.3841510040675
user_input = np.array(user_input).reshape(1, -1)
user_input_scaled = scaler.transform(user_input)

# Predict Temperature for user input
predicted_temp = cv.predict(user_input_scaled)

print(f"Predicted temperature with decision tree regression: {predicted_temp[0]}")
# Out:
# Enter value for Humidity:  49.963210
# Enter value for Wind Speed:  17.488459
# Enter value for Pressure:  	1006.693077
# Predicted temperature with decision tree regression: 145.0165740182623
# C:\Users\HP\vanshu\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
#RANDOMFOREST

# %%
#RANDOMFOREST REGRESSOR
from sklearn.ensemble import RandomForestRegressor
dt_regressor = RandomForestRegressor(random_state=890)
treemodel=RandomForestRegressor(max_depth=2)
treemodel
# Out:
# RandomForestRegressor(max_depth=2)

# %%
treemodel=RandomForestRegressor(max_depth=2)
treemodel
# Out:
# RandomForestRegressor(max_depth=2)

# %%
treemodel.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=2)

# %%
#postprunning technique
treemodel=RandomForestRegressor()
treemodel
# Out:
# RandomForestRegressor()

# %%
treemodel.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = treemodel.predict(x_test)
y_pred
# Out:
# array([144.89943837, 141.98572145, 147.16834306, ..., 147.78759652,
#        155.28043689, 154.92925685])

# %%
from sklearn.metrics import r2_score
score = r2_score(y_pred,y_test)
print(score)
# Out:
# 0.9820219594572613

# %%
import time
import random
from sklearn.metrics import roc_curve,auc
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import KFold,cross_val_score
from sklearn.model_selection import train_test_split,GridSearchCV
from urllib.request import urlopen
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
fit_rf = RandomForestRegressor(random_state = 10)

# %%
param_grid = {
    'n_estimators': [int(x) for x in np.linspace(start=100, stop=1000, num=10)],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth': [int(x) for x in np.linspace(10, 110, num=11)] + [None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False]
}

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
treemodel=RandomForestRegressor()
cv=RandomizedSearchCV(treemodel,param_distributions=param_grid,cv=5)

# %%
cv.fit(x_train,y_train)
cv.best_params_
cv.predict(x_test)
y_pred=cv.predict(x_test)
score = r2_score(y_pred,y_test)
print(score)
# Out:
# C:\Users\HP\vanshu\Lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# C:\Users\HP\vanshu\Lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# ...

# %%
df
# Out:
#         Humidity  Wind Speed     Pressure  Temperature
# 0      49.963210   17.488459  1006.693077   145.331225
# 1      96.057145   26.136137  1034.403088   165.669988
# 2      78.559515   19.693337  1029.656791   161.166444
# 3      67.892679    2.915590  1020.309354   158.458275
# 4      32.481491    6.495308  1009.569241   144.024266
# ...          ...         ...          ...          ...
# 14909  72.070679   33.329641   997.158044   143.164792
# 14910  34.223867   26.173847  1023.660355   144.480725
# 14911  24.099163    0.680955  1003.434061   138.531646
# 14912  74.636927   14.035169  1014.538453   156.725633
# 14913  40.086322    9.008929  1016.214783   147.734672
#
# [14914 rows x 4 columns]

# %%
user_input = []
for feature in x.columns:
  value = float(input(f"Enter value for {feature}: "))
  user_input.append(value)

# Reshape and scale user input
user_input = np.array(user_input).reshape(1, -1)
user_input_scaled = scaler.transform(user_input)

# Predict profit for user input
predicted_temp = cv.predict(user_input_scaled)

print(f"Predicted temperature with random forest regression: {predicted_temp[0]}")
# Out:
# Enter value for Humidity:  96.057145
# Enter value for Wind Speed:  26.136137
# Enter value for Pressure:  1034.403088
# Predicted temperature with random forest regression: 166.7513388231687
# C:\Users\HP\vanshu\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd

# Updated dictionary containing models and their accuracies
data = {
    'Model': [
        'Multilinear Regression', 
        'Decision Tree Regressor', 
        'Random Forest Regressor', 
        
    ],
    'Accuracy': [
        0.9849601213096258, 
        0.9720442303440369, 
        0.9849691479029954 
        
    ]
}

# Creating DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
df
# Out:
#                      Model  Accuracy
# 0   Multilinear Regression  0.984960
# 1  Decision Tree Regressor  0.972044
# 2  Random Forest Regressor  0.984969

# %%
import pandas as pd

# Dictionary containing models and their predicted prices
data = {
    'Multilinear Regression': [ 144.17602683093133,161.50811447159617, 157.9363795111213],
    'Decision Tree Regressor':[ 144.64274629684397,161.9807681540074, 157.74768027905296],
    'Random Forest Regressor':[ 144.3841510040675,162.04660537911514,158.48965663485118],
    'Actual Value': [145.331225,161.166444,158.458275]}

# Creating DataFrame
df_prices = pd.DataFrame(data,index=['predicted value(0th row)','predicted value(2nd row)','predicted value(3rd row)'])

# Display the DataFrame
df_prices
# Out:
#                           Multilinear Regression  Decision Tree Regressor  \
# predicted value(0th row)              144.176027               144.642746
# predicted value(2nd row)              161.508114               161.980768
# predicted value(3rd row)              157.936380               157.747680
#
#                           Random Forest Regressor  Actual Value
# predicted value(0th row)               144.384151    145.331225
# predicted value(2nd row)               162.046605    161.166444
# predicted value(3rd row)               158.489657    158.458275
